# %%
import torch
import torch.nn as nn
from torchvision.models import vision_transformer, vit_h_14, ViT_H_14_Weights

vit_h_14(weights=ViT_H_14_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/vit_h_14_swag-80465313.pth" to /Users/shane/.cache/torch/hub/checkpoints/vit_h_14_swag-80465313.pth
#   0%|          | 0.00/2.36G [00:00<?, ?B/s]
# VisionTransformer(
#   (conv_proj): Conv2d(3, 1280, kernel_size=(14, 14), stride=(14, 14))
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (layers): Sequential(
#       (encoder_layer_0): EncoderBlock(
#         (ln_1): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=1280, out_features=1280, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((1280,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate=none)
#           (2): Dropout(p=0.0, inplace=False)
# ...

# %%
att = nn.MultiheadAttention(2, 1)
att
# Out:
# MultiheadAttention(
#   (out_proj): NonDynamicallyQuantizableLinear(in_features=2, out_features=2, bias=True)
# )
